# %%
import os
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
img_width=256; img_height=256
batch_size=16

# %% [markdown]
# ## Kaggle-simplified bees dataset

# %%
Training_dir = 'C:/Users/ADMIN/Desktop/datasets/bees/train'

# %%
Training_dir
# Out:
# 'C:/Users/ADMIN/Desktop/datasets/bees/train'

# %%
### trainset
train_datagen = ImageDataGenerator(rescale = 1/255.0)

# %%
train_generator = train_datagen.flow_from_directory(Training_dir,
                                                    batch_size=batch_size,
                                                    class_mode='categorical',
                                                    target_size=(img_height, img_width)
                                                    )
# Out:
# Found 4143 images belonging to 4 classes.

# %%
Validation_dir = 'C:/Users/ADMIN/Desktop/datasets/bees/test/'

# %%
Validation_dir
# Out:
# 'C:/Users/ADMIN/Desktop/datasets/bees/test/'

# %%
###testset
validation_datagen = ImageDataGenerator(rescale = 1/255.0)

# %%
validation_generator = validation_datagen.flow_from_directory(Validation_dir,
                                                              batch_size=batch_size,
                                                              class_mode='categorical',
                                                              target_size=(img_height, img_width))
# Out:
# Found 500 images belonging to 4 classes.

# %%
callbacks = EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='auto')
best_model_file = 'C:/Users/ADMIN/Desktop/datasets/bees/validate'
best_model = ModelCheckpoint(best_model_file, monitor='accuracy', verbose = 1, save_best_only = True)

# %%
model = tf.keras.models.Sequential([
    Conv2D(16, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(2, 2),
    
    Conv2D(32, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    
    Conv2D(64, (3, 3), activation='relu'),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    
    Conv2D(128, (3, 3), activation='relu'),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(2, 2),
    
    Flatten(),
    Dense(512, activation='relu'),
    Dense(512, activation='relu'),
    Dense(4, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 254, 254, 16)      448
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 127, 127, 16)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 125, 125, 32)      4640
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 60, 60, 64)        18496
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 58, 58, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 29, 29, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 27, 27, 128)       73856
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 25, 25, 128)       147584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 12, 12, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               9437696
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_5 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 9,984,356
# Trainable params: 9,984,356
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics =['accuracy'])

# %%
history = model.fit_generator(train_generator,
                              epochs=30,
                              verbose=1,
                              validation_data=validation_generator,
                              callbacks = [best_model, callbacks]
                              )
# Out:
# Epoch 1/30
# 259/259 [==============================] - 471s 2s/step - loss: 0.8806 - accuracy: 0.6753 - val_loss: 0.4767 - val_accuracy: 0.8280
#
# Epoch 00001: accuracy improved from -inf to 0.74077, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 2/30
# 259/259 [==============================] - 419s 2s/step - loss: 0.4312 - accuracy: 0.8512 - val_loss: 0.4643 - val_accuracy: 0.8360
#
# Epoch 00002: accuracy improved from 0.74077 to 0.85035, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 3/30
# 259/259 [==============================] - 418s 2s/step - loss: 0.3292 - accuracy: 0.8823 - val_loss: 0.4123 - val_accuracy: 0.8660
#
# Epoch 00003: accuracy improved from 0.85035 to 0.89380, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 4/30
# 259/259 [==============================] - 419s 2s/step - loss: 0.2618 - accuracy: 0.9056 - val_loss: 0.2965 - val_accuracy: 0.8880
#
# Epoch 00004: accuracy improved from 0.89380 to 0.90152, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 5/30
# 259/259 [==============================] - 420s 2s/step - loss: 0.1961 - accuracy: 0.9343 - val_loss: 0.2775 - val_accuracy: 0.8840
#
# Epoch 00005: accuracy improved from 0.90152 to 0.93459, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 6/30
# 259/259 [==============================] - 430s 2s/step - loss: 0.1342 - accuracy: 0.9477 - val_loss: 0.2593 - val_accuracy: 0.9000
#
# Epoch 00006: accuracy improved from 0.93459 to 0.94545, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 7/30
# 259/259 [==============================] - 429s 2s/step - loss: 0.1617 - accuracy: 0.9457 - val_loss: 0.2806 - val_accuracy: 0.9040
#
# Epoch 00007: accuracy did not improve from 0.94545
# Epoch 8/30
# 259/259 [==============================] - 430s 2s/step - loss: 0.1293 - accuracy: 0.9605 - val_loss: 0.2295 - val_accuracy: 0.9220
#
# Epoch 00008: accuracy improved from 0.94545 to 0.96042, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 9/30
# 259/259 [==============================] - 455s 2s/step - loss: 0.0831 - accuracy: 0.9740 - val_loss: 0.6877 - val_accuracy: 0.8080
#
# Epoch 00009: accuracy improved from 0.96042 to 0.97176, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 10/30
# 259/259 [==============================] - 432s 2s/step - loss: 0.1077 - accuracy: 0.9719 - val_loss: 0.2678 - val_accuracy: 0.9180
#
# Epoch 00010: accuracy improved from 0.97176 to 0.97514, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 11/30
# 259/259 [==============================] - 431s 2s/step - loss: 0.0799 - accuracy: 0.9753 - val_loss: 0.2483 - val_accuracy: 0.9320
#
# Epoch 00011: accuracy did not improve from 0.97514
# Epoch 12/30
# 259/259 [==============================] - 437s 2s/step - loss: 0.0298 - accuracy: 0.9907 - val_loss: 0.2901 - val_accuracy: 0.9220
#
# Epoch 00012: accuracy improved from 0.97514 to 0.98359, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 13/30
# 259/259 [==============================] - 430s 2s/step - loss: 0.0275 - accuracy: 0.9912 - val_loss: 0.1863 - val_accuracy: 0.9420
#
# Epoch 00013: accuracy improved from 0.98359 to 0.99131, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 14/30
# 259/259 [==============================] - 430s 2s/step - loss: 0.0212 - accuracy: 0.9936 - val_loss: 0.2527 - val_accuracy: 0.9440
#
# Epoch 00014: accuracy did not improve from 0.99131
# Epoch 15/30
# 259/259 [==============================] - 430s 2s/step - loss: 0.0502 - accuracy: 0.9871 - val_loss: 0.3087 - val_accuracy: 0.9340
#
# Epoch 00015: accuracy did not improve from 0.99131
# Epoch 16/30
# 259/259 [==============================] - 426s 2s/step - loss: 0.0162 - accuracy: 0.9956 - val_loss: 0.2732 - val_accuracy: 0.9460
#
# Epoch 00016: accuracy improved from 0.99131 to 0.99590, saving model to C:/Users/ADMIN/Desktop/datasets/bees\validate
# INFO:tensorflow:Assets written to: C:/Users/ADMIN/Desktop/datasets/bees\validate\assets
# Epoch 17/30
# 259/259 [==============================] - 414s 2s/step - loss: 0.0155 - accuracy: 0.9947 - val_loss: 0.2887 - val_accuracy: 0.9040
#
# Epoch 00017: accuracy did not improve from 0.99590
# Epoch 18/30
# 259/259 [==============================] - 417s 2s/step - loss: 0.0574 - accuracy: 0.9821 - val_loss: 0.2769 - val_accuracy: 0.9240
#
# Epoch 00018: accuracy did not improve from 0.99590
# Epoch 00018: early stopping

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

# %%
epochs=range(len(acc))

# %%
fig = plt.figure(figsize=(20,10))
plt.plot(epochs, acc, 'r', label="Training Accuracy")
plt.plot(epochs, val_acc, 'b', label="Validation Accuracy")
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc='lower right')
plt.show()

# %%
fig2 = plt.figure(figsize=(20,10))
plt.plot(epochs, loss, 'r', label="Training Loss")
plt.plot(epochs, val_loss, 'b', label="Validation Loss")
plt.legend(loc='upper right')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and validation loss')
# Out:
# Text(0.5, 1.0, 'Training and validation loss')
